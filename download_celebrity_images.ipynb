# %%
import os
import requests
from bs4 import BeautifulSoup
from PIL import Image
from io import BytesIO
import time

# 全局变量：名人分类和名字名录
celebrity_dict = {
    "Politician": ["George Washington", "Abraham Lincoln", "Donald Trump", "Elizabeth II", "Barack Obama"],
    "Actor": ["Charlie Chaplin", "Natalie Portman", "Leonardo DiCaprio", "Tom Hanks", "Jackie Chan"],
    "Director": ["Alfred Hitchcock", "Steven Spielberg", "Quentin Tarantino", "Martin Scorsese", "James Cameron"],
    "Poet": ["Emily Dickinson", "Li Bai", "William Wordsworth", "Rumi", "Jorge Luis Borges"],
    "Artist": ["Pablo Picasso", "Vincent van Gogh", "Leonardo da Vinci", "Claude Monet", "Michelangelo"],
    "Musician": ["Ludwig van Beethoven", "Wolfgang Amadeus Mozart", "Johann Sebastian Bach", "David Bowie", "Miles Davis"],
    "Athlete": ["Usain Bolt", "Michael Phelps", "Serena Williams", "Cristiano Ronaldo", "Muhammad Ali"],
    "Singer": ["Taylor Swift", "Han Hong", "Elvis Presley", "Freddie Mercury", "Whitney Houston"],
    "Writer": ["William Shakespeare", "Lu Xun", "Mark Twain", "Leo Tolstoy", "Gabriel García Márquez"],
    "Scientist": ["Isaac Newton", "Albert Einstein", "Thomas Edison", "Nikola Tesla", "Tu Youyou"]
}

# 爬取并保存图片
def download_images(query, save_folder, num_images=10):
    search_url = f"https://www.bing.com/images/search?q={query}&FORM=HDRSC2"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36"}
    
    response = requests.get(search_url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to get response for {query}")
        return
    
    soup = BeautifulSoup(response.text, "html.parser")
    img_tags = soup.find_all("img", class_="mimg")
    
    if not os.path.exists(save_folder):
        os.makedirs(save_folder)

    count = 0
    for i, img_tag in enumerate(img_tags):
        if count >= num_images:
            break
        img_url = img_tag.get("src") or img_tag.get("data-src")
        if img_url:
            try:
                img_data = requests.get(img_url, timeout=10).content
                img = Image.open(BytesIO(img_data))
                img_format = img.format if img.format else "jpg"
                img.save(os.path.join(save_folder, f"{query.replace(' ', '_')}_{count+1}.{img_format.lower()}"))
                count += 1
                print(f"Saved: {query} - {count}")
            except Exception as e:
                print(f"Error downloading {img_url}: {e}")
        time.sleep(1)
    print(f"{count}/{num_images} images downloaded for {query}")

# 主函数：遍历名人字典，爬取图片
def main(base_folder="Celebrity_Dataset", images_per_person=10):
    if not os.path.exists(base_folder):
        os.makedirs(base_folder)

    for category, celebrities in celebrity_dict.items():
        category_folder = os.path.join(base_folder, category)
        if not os.path.exists(category_folder):
            os.makedirs(category_folder)
        
        for celeb in celebrities:
            celeb_folder = os.path.join(category_folder, celeb.replace(" ", "_"))
            print(f"Downloading images for: {celeb} in category: {category}")
            download_images(celeb, celeb_folder, images_per_person)
            print("-"*50)

if __name__ == "__main__":
    main()
# Out:
# Downloading images for: George Washington in category: Politician
# Saved: George Washington - 1
# Saved: George Washington - 2
# Saved: George Washington - 3
# Saved: George Washington - 4
# Saved: George Washington - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for George Washington
# --------------------------------------------------
# Downloading images for: Abraham Lincoln in category: Politician
# Saved: Abraham Lincoln - 1
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Saved: Abraham Lincoln - 4
# Saved: Abraham Lincoln - 5
# Saved: Abraham Lincoln - 6
# Saved: Abraham Lincoln - 7
# Saved: Abraham Lincoln - 8
# Saved: Abraham Lincoln - 9
# Error downloading ...: No connection adapters were found for '...'
# 7/10 images downloaded for Abraham Lincoln
# --------------------------------------------------
# Downloading images for: Donald Trump in category: Politician
# Saved: Donald Trump - 1
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 1/10 images downloaded for Donald Trump
# --------------------------------------------------
# Downloading images for: Elizabeth II in category: Politician
# Saved: Elizabeth II - 1
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Saved: Elizabeth II - 4
# Saved: Elizabeth II - 5
# Saved: Elizabeth II - 6
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Saved: Elizabeth II - 9
# Saved: Elizabeth II - 10
# 6/10 images downloaded for Elizabeth II
# --------------------------------------------------
# Downloading images for: Barack Obama in category: Politician
# Saved: Barack Obama - 1
# Saved: Barack Obama - 2
# Saved: Barack Obama - 3
# Saved: Barack Obama - 4
# Saved: Barack Obama - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for Barack Obama
# --------------------------------------------------
# Downloading images for: Charlie Chaplin in category: Actor
# Saved: Charlie Chaplin - 1
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Saved: Charlie Chaplin - 4
# Saved: Charlie Chaplin - 5
# Error downloading ...: No connection adapters were found for '...'
# Saved: Charlie Chaplin - 7
# Saved: Charlie Chaplin - 8
# Saved: Charlie Chaplin - 9
# Saved: Charlie Chaplin - 10
# 7/10 images downloaded for Charlie Chaplin
# --------------------------------------------------
# Downloading images for: Natalie Portman in category: Actor
# Saved: Natalie Portman - 1
# Error downloading ...: No connection adapters were found for '...'
# Saved: Natalie Portman - 3
# Saved: Natalie Portman - 4
# Saved: Natalie Portman - 5
# Saved: Natalie Portman - 6
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Saved: Natalie Portman - 9
# Saved: Natalie Portman - 10
# 7/10 images downloaded for Natalie Portman
# --------------------------------------------------
# Downloading images for: Leonardo DiCaprio in category: Actor
# Saved: Leonardo DiCaprio - 1
# Error downloading ...: No connection adapters were found for '...'
# Saved: Leonardo DiCaprio - 3
# Saved: Leonardo DiCaprio - 4
# Saved: Leonardo DiCaprio - 5
# Saved: Leonardo DiCaprio - 6
# Saved: Leonardo DiCaprio - 7
# Error downloading ...: No connection adapters were found for '...'
# Saved: Leonardo DiCaprio - 9
# Saved: Leonardo DiCaprio - 10
# 8/10 images downloaded for Leonardo DiCaprio
# --------------------------------------------------
# Downloading images for: Tom Hanks in category: Actor
# Saved: Tom Hanks - 1
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Saved: Tom Hanks - 4
# Saved: Tom Hanks - 5
# Saved: Tom Hanks - 6
# Saved: Tom Hanks - 7
# Saved: Tom Hanks - 8
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 6/10 images downloaded for Tom Hanks
# --------------------------------------------------
# Downloading images for: Jackie Chan in category: Actor
# Saved: Jackie Chan - 1
# Saved: Jackie Chan - 2
# Saved: Jackie Chan - 3
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 3/10 images downloaded for Jackie Chan
# --------------------------------------------------
# Downloading images for: Alfred Hitchcock in category: Director
# Saved: Alfred Hitchcock - 1
# Saved: Alfred Hitchcock - 2
# Saved: Alfred Hitchcock - 3
# Saved: Alfred Hitchcock - 4
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 4/10 images downloaded for Alfred Hitchcock
# --------------------------------------------------
# Downloading images for: Steven Spielberg in category: Director
# Saved: Steven Spielberg - 1
# Saved: Steven Spielberg - 2
# Saved: Steven Spielberg - 3
# Saved: Steven Spielberg - 4
# Saved: Steven Spielberg - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for Steven Spielberg
# --------------------------------------------------
# Downloading images for: Quentin Tarantino in category: Director
# Saved: Quentin Tarantino - 1
# Saved: Quentin Tarantino - 2
# Saved: Quentin Tarantino - 3
# Saved: Quentin Tarantino - 4
# Saved: Quentin Tarantino - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for Quentin Tarantino
# --------------------------------------------------
# Downloading images for: Martin Scorsese in category: Director
# Saved: Martin Scorsese - 1
# Saved: Martin Scorsese - 2
# Saved: Martin Scorsese - 3
# Saved: Martin Scorsese - 4
# Saved: Martin Scorsese - 5
# Saved: Martin Scorsese - 6
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 6/10 images downloaded for Martin Scorsese
# --------------------------------------------------
# Downloading images for: James Cameron in category: Director
# Saved: James Cameron - 1
# Saved: James Cameron - 2
# Saved: James Cameron - 3
# Saved: James Cameron - 4
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 4/10 images downloaded for James Cameron
# --------------------------------------------------
# Downloading images for: Emily Dickinson in category: Poet
# Saved: Emily Dickinson - 1
# Saved: Emily Dickinson - 2
# Saved: Emily Dickinson - 3
# Saved: Emily Dickinson - 4
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 4/10 images downloaded for Emily Dickinson
# --------------------------------------------------
# Downloading images for: Li Bai in category: Poet
# Saved: Li Bai - 1
# Saved: Li Bai - 2
# Saved: Li Bai - 3
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 3/10 images downloaded for Li Bai
# --------------------------------------------------
# Downloading images for: William Wordsworth in category: Poet
# Saved: William Wordsworth - 1
# Saved: William Wordsworth - 2
# Saved: William Wordsworth - 3
# Saved: William Wordsworth - 4
# Saved: William Wordsworth - 5
# Saved: William Wordsworth - 6
# Saved: William Wordsworth - 7
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 7/10 images downloaded for William Wordsworth
# --------------------------------------------------
# Downloading images for: Rumi in category: Poet
# Saved: Rumi - 1
# Saved: Rumi - 2
# Saved: Rumi - 3
# Saved: Rumi - 4
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 4/10 images downloaded for Rumi
# --------------------------------------------------
# Downloading images for: Jorge Luis Borges in category: Poet
# Saved: Jorge Luis Borges - 1
# Saved: Jorge Luis Borges - 2
# Saved: Jorge Luis Borges - 3
# Saved: Jorge Luis Borges - 4
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 4/10 images downloaded for Jorge Luis Borges
# --------------------------------------------------
# Downloading images for: Pablo Picasso in category: Artist
# Saved: Pablo Picasso - 1
# Saved: Pablo Picasso - 2
# Saved: Pablo Picasso - 3
# Saved: Pablo Picasso - 4
# Saved: Pablo Picasso - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for Pablo Picasso
# --------------------------------------------------
# Downloading images for: Vincent van Gogh in category: Artist
# Saved: Vincent van Gogh - 1
# Saved: Vincent van Gogh - 2
# Saved: Vincent van Gogh - 3
# Saved: Vincent van Gogh - 4
# Saved: Vincent van Gogh - 5
# Saved: Vincent van Gogh - 6
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 6/10 images downloaded for Vincent van Gogh
# --------------------------------------------------
# Downloading images for: Leonardo da Vinci in category: Artist
# Saved: Leonardo da Vinci - 1
# Saved: Leonardo da Vinci - 2
# Saved: Leonardo da Vinci - 3
# Saved: Leonardo da Vinci - 4
# Saved: Leonardo da Vinci - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for Leonardo da Vinci
# --------------------------------------------------
# Downloading images for: Claude Monet in category: Artist
# Saved: Claude Monet - 1
# Saved: Claude Monet - 2
# Saved: Claude Monet - 3
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 3/10 images downloaded for Claude Monet
# --------------------------------------------------
# Downloading images for: Michelangelo in category: Artist
# Saved: Michelangelo - 1
# Saved: Michelangelo - 2
# Saved: Michelangelo - 3
# Saved: Michelangelo - 4
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 4/10 images downloaded for Michelangelo
# --------------------------------------------------
# Downloading images for: Ludwig van Beethoven in category: Musician
# Saved: Ludwig van Beethoven - 1
# Saved: Ludwig van Beethoven - 2
# Saved: Ludwig van Beethoven - 3
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 3/10 images downloaded for Ludwig van Beethoven
# --------------------------------------------------
# Downloading images for: Wolfgang Amadeus Mozart in category: Musician
# Saved: Wolfgang Amadeus Mozart - 1
# Saved: Wolfgang Amadeus Mozart - 2
# Saved: Wolfgang Amadeus Mozart - 3
# Saved: Wolfgang Amadeus Mozart - 4
# Saved: Wolfgang Amadeus Mozart - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for Wolfgang Amadeus Mozart
# --------------------------------------------------
# Downloading images for: Johann Sebastian Bach in category: Musician
# Saved: Johann Sebastian Bach - 1
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Saved: Johann Sebastian Bach - 4
# Saved: Johann Sebastian Bach - 5
# Saved: Johann Sebastian Bach - 6
# Saved: Johann Sebastian Bach - 7
# Saved: Johann Sebastian Bach - 8
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 6/10 images downloaded for Johann Sebastian Bach
# --------------------------------------------------
# Downloading images for: David Bowie in category: Musician
# Saved: David Bowie - 1
# Saved: David Bowie - 2
# Saved: David Bowie - 3
# Saved: David Bowie - 4
# Saved: David Bowie - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for David Bowie
# --------------------------------------------------
# Downloading images for: Miles Davis in category: Musician
# Saved: Miles Davis - 1
# Saved: Miles Davis - 2
# Saved: Miles Davis - 3
# Saved: Miles Davis - 4
# Saved: Miles Davis - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for Miles Davis
# --------------------------------------------------
# Downloading images for: Usain Bolt in category: Athlete
# Saved: Usain Bolt - 1
# Saved: Usain Bolt - 2
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 2/10 images downloaded for Usain Bolt
# --------------------------------------------------
# Downloading images for: Michael Phelps in category: Athlete
# Saved: Michael Phelps - 1
# Saved: Michael Phelps - 2
# Saved: Michael Phelps - 3
# Saved: Michael Phelps - 4
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 4/10 images downloaded for Michael Phelps
# --------------------------------------------------
# Downloading images for: Serena Williams in category: Athlete
# Saved: Serena Williams - 1
# Saved: Serena Williams - 2
# Saved: Serena Williams - 3
# Saved: Serena Williams - 4
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 4/10 images downloaded for Serena Williams
# --------------------------------------------------
# Downloading images for: Cristiano Ronaldo in category: Athlete
# Saved: Cristiano Ronaldo - 1
# Saved: Cristiano Ronaldo - 2
# Saved: Cristiano Ronaldo - 3
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 3/10 images downloaded for Cristiano Ronaldo
# --------------------------------------------------
# Downloading images for: Muhammad Ali in category: Athlete
# Saved: Muhammad Ali - 1
# Saved: Muhammad Ali - 2
# Saved: Muhammad Ali - 3
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 3/10 images downloaded for Muhammad Ali
# --------------------------------------------------
# Downloading images for: Taylor Swift in category: Singer
# Saved: Taylor Swift - 1
# Error downloading ...: No connection adapters were found for '...'
# Saved: Taylor Swift - 3
# Saved: Taylor Swift - 4
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Saved: Taylor Swift - 7
# Saved: Taylor Swift - 8
# Saved: Taylor Swift - 9
# Saved: Taylor Swift - 10
# 7/10 images downloaded for Taylor Swift
# --------------------------------------------------
# Downloading images for: Han Hong in category: Singer
# Saved: Han Hong - 1
# Saved: Han Hong - 2
# Saved: Han Hong - 3
# Saved: Han Hong - 4
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 4/10 images downloaded for Han Hong
# --------------------------------------------------
# Downloading images for: Elvis Presley in category: Singer
# Saved: Elvis Presley - 1
# Saved: Elvis Presley - 2
# Saved: Elvis Presley - 3
# Saved: Elvis Presley - 4
# Saved: Elvis Presley - 5
# Saved: Elvis Presley - 6
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 6/10 images downloaded for Elvis Presley
# --------------------------------------------------
# Downloading images for: Freddie Mercury in category: Singer
# Saved: Freddie Mercury - 1
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Saved: Freddie Mercury - 4
# Saved: Freddie Mercury - 5
# Saved: Freddie Mercury - 6
# Saved: Freddie Mercury - 7
# Saved: Freddie Mercury - 8
# Error downloading ...: No connection adapters were found for '...'
# Saved: Freddie Mercury - 10
# 7/10 images downloaded for Freddie Mercury
# --------------------------------------------------
# Downloading images for: Whitney Houston in category: Singer
# Saved: Whitney Houston - 1
# Saved: Whitney Houston - 2
# Saved: Whitney Houston - 3
# Saved: Whitney Houston - 4
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 4/10 images downloaded for Whitney Houston
# --------------------------------------------------
# Downloading images for: William Shakespeare in category: Writer
# Saved: William Shakespeare - 1
# Saved: William Shakespeare - 2
# Saved: William Shakespeare - 3
# Saved: William Shakespeare - 4
# Saved: William Shakespeare - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for William Shakespeare
# --------------------------------------------------
# Downloading images for: Lu Xun in category: Writer
# Saved: Lu Xun - 1
# Saved: Lu Xun - 2
# Saved: Lu Xun - 3
# Saved: Lu Xun - 4
# Saved: Lu Xun - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for Lu Xun
# --------------------------------------------------
# Downloading images for: Mark Twain in category: Writer
# Saved: Mark Twain - 1
# Saved: Mark Twain - 2
# Saved: Mark Twain - 3
# Saved: Mark Twain - 4
# Saved: Mark Twain - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for Mark Twain
# --------------------------------------------------
# Downloading images for: Leo Tolstoy in category: Writer
# Saved: Leo Tolstoy - 1
# Error downloading ...: No connection adapters were found for '...'
# Saved: Leo Tolstoy - 3
# Saved: Leo Tolstoy - 4
# Saved: Leo Tolstoy - 5
# Saved: Leo Tolstoy - 6
# Saved: Leo Tolstoy - 7
# Saved: Leo Tolstoy - 8
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 7/10 images downloaded for Leo Tolstoy
# --------------------------------------------------
# Downloading images for: Gabriel García Márquez in category: Writer
# Saved: Gabriel García Márquez - 1
# Saved: Gabriel García Márquez - 2
# Saved: Gabriel García Márquez - 3
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 3/10 images downloaded for Gabriel García Márquez
# --------------------------------------------------
# Downloading images for: Isaac Newton in category: Scientist
# Saved: Isaac Newton - 1
# Saved: Isaac Newton - 2
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 2/10 images downloaded for Isaac Newton
# --------------------------------------------------
# Downloading images for: Albert Einstein in category: Scientist
# Saved: Albert Einstein - 1
# Saved: Albert Einstein - 2
# Saved: Albert Einstein - 3
# Saved: Albert Einstein - 4
# Saved: Albert Einstein - 5
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 5/10 images downloaded for Albert Einstein
# --------------------------------------------------
# Downloading images for: Thomas Edison in category: Scientist
# Saved: Thomas Edison - 1
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Saved: Thomas Edison - 4
# Saved: Thomas Edison - 5
# Saved: Thomas Edison - 6
# Saved: Thomas Edison - 7
# Saved: Thomas Edison - 8
# Saved: Thomas Edison - 9
# Saved: Thomas Edison - 10
# 8/10 images downloaded for Thomas Edison
# --------------------------------------------------
# Downloading images for: Nikola Tesla in category: Scientist
# Saved: Nikola Tesla - 1
# Saved: Nikola Tesla - 2
# Saved: Nikola Tesla - 3
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 3/10 images downloaded for Nikola Tesla
# --------------------------------------------------
# Downloading images for: Tu Youyou in category: Scientist
# Saved: Tu Youyou - 1
# Saved: Tu Youyou - 2
# Saved: Tu Youyou - 3
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# Error downloading ...: No connection adapters were found for '...'
# 3/10 images downloaded for Tu Youyou
# --------------------------------------------------
